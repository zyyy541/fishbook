# %% [markdown]
# ![三层神经网络](..\image\2.png)

# %%
# 对于上面的神经网络用代码实现
import numpy as np
X = np.array([1.0,0.5])
W1 = np.array([[0.1,0.3,0.5],[0.2,0.4,0.6]])
B1 = np.array([0.1,0.2,0.3])
A1 = np.dot(X,W1)+B1
print(A1)
# Out:
# [0.3 0.7 1.1]

# %%
# 神经源中在重新设置激活函数
# 如下图所示

# %% [markdown]
# ![三层神经网络](..\image\3.png)
