# %%
import numpy as np
import matplotlib.pylab as plt

# %%
def step_function(x):
    y = x > 0
    return y.astype(np.int32)

# 实现跃迁函数，转为np数组能够使用，先转为布尔类型，再转为整数类型

# %%
# 跃迁函数的图像
x = np.arange(-5.0,5.0,0.1)
def step_function(x):
    return np.array(x>0,dtype=np.int32)
y = step_function(x)
plt.plot(x,y)
plt.ylim(-0.1,1.1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# sigmoid函数实现
def sigmoid(x):
    return 1/(1+np.exp(-x))

# %%
# sigmoid函数的图像
x = np.arange(-5.0,5.0,0.1)
def step_function(x):
    return np.array(x>0,dtype=np.int32)
y = sigmoid(x)
plt.plot(x,y)
plt.ylim(-0.1,1.1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 神经网络的激活函数必须是非线性函数
# 原因：假设激活函数是h = c*x，经过了三层神经网络之后变为h(h(h(x))),就是c*c*c*x，这完全可以使用h = a*x来表示，那么这三层神经网络就没用了

# %%
# relu函数：大于0直接输出x,小于0输出0
# 定义relu函数
def relu(x):
    return np.maximum(0,x)

# %%
# relu函数图像
x = np.arange(-5.0,5.0,0.1)
y = relu(x)
plt.plot(x,y)
plt.ylim(-1,5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
